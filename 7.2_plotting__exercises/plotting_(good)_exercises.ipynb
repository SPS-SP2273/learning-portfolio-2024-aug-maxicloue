# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Exercise 1

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='g', alpha=.125)
axes[0, 0].set_xlabel('Angle (radians)')
axes[0, 0].text(0, 0, 'I am [0, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, cos_x, -2, color='r', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='lower right', frameon=False)
axes[0, 1].text(0, 0, 'I am [0, 1]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, fun1_x, 0, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()
axes[1, 0].text(0, 0, 'I am [1, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, 10, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()
axes[1, 1].text(0, 0, 'I am [1, 1]!', fontsize=30,
                horizontalalignment='center')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show(block=False)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\c'
# <>:15: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\c'
# <>:15: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:13: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:15: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:16: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:24: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:26: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:34: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:36: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:40: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:40: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:40: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:40: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:46: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3338193572.py:47: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(13, 8), 
                         sharex = True, sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -2, color='r', alpha=.125)
axes[0, 0].legend(loc = 'upper right', frameon=True)


#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -2, color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right', frameon=True)
axes[0, 1].set_title('$\sin x$ & $\sin^2 x$')


#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='sin 2x')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend(loc = 'upper right', frameon = True)


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='sin 2x')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()
axes[1, 1].set_xlabel('Angle (radians)')


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)
    

plt.xlim(-np.pi, np.pi)
plt.show(block=False)
plt.tight_layout()

plt.savefig('simple-plot.jpg', dpi = 500)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:17: SyntaxWarning: invalid escape sequence '\c'
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:17: SyntaxWarning: invalid escape sequence '\c'
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:39: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:14: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:16: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:17: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:24: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:26: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:29: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].set_title('$\sin x$ & $\sin^2 x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:35: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:39: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:39: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:39: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:39: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/6x/h9_td43d6xz5yqzyqmhsr4nm0000gn/T/ipykernel_89691/3926217416.py:45: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')
