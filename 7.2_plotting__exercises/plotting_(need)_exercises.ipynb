# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %%
conda install matplotlib -c conda-forge
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/clouemax/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       hd74edd7_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd74edd7_2          16 KB  conda-forge
#     ca-certificates-2024.8.30  |       hf0a4a13_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     contourpy-1.3.0            |  py312h6142ec9_0         242 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     fonttools-4.53.1           |  py312h7e5086c_0         2.6 MB  conda-forge
#     freetype-2.12.1            |       hadb7bae_2         582 KB  conda-forge
#     kiwisolver-1.4.5           |  py312h6142ec9_2          60 KB  conda-forge
#     lcms2-2.16                 |       ha0e7c42_0         207 KB  conda-forge
#     lerc-4.0.0                 |       h9a09cb3_0         211 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd74edd7_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd74edd7_2          28 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd74edd7_2         273 KB  conda-forge
#     libdeflate-1.20            |       h93a5062_0          53 KB  conda-forge
#     libjpeg-turbo-3.0.0        |       hb547adb_1         535 KB  conda-forge
#     libpng-1.6.43              |       h091b4b1_0         258 KB  conda-forge
#     libtiff-4.6.0              |       h07db509_3         233 KB  conda-forge
#     libwebp-base-1.4.0         |       h93a5062_0         281 KB  conda-forge
#     libxcb-1.15                |       hf346824_0         327 KB  conda-forge
#     matplotlib-3.9.2           |  py312h1f38498_0           9 KB  conda-forge
#     matplotlib-base-3.9.2      |  py312h32d6e5a_0         7.5 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     openjpeg-2.5.2             |       h9f1df11_0         309 KB  conda-forge
#     openssl-3.3.1              |       h8359307_3         2.8 MB  conda-forge
#     pillow-10.3.0              |  py312h8a801b1_0        40.8 MB  conda-forge
#     pthread-stubs-0.4          |    h27ca646_1001           6 KB  conda-forge
#     pyparsing-3.1.4            |     pyhd8ed1ab_0          88 KB  conda-forge
#     qhull-2020.2               |       h420ef59_5         504 KB  conda-forge
#     xorg-libxau-1.0.11         |       hb547adb_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h27ca646_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        58.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py312h6142ec9_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.53.1-py312h7e5086c_0
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.5-py312h6142ec9_2
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py312h1f38498_0
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py312h32d6e5a_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py312h8a801b1_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-h27ca646_1001
#   pyparsing          conda-forge/noarch::pyparsing-3.1.4-pyhd8ed1ab_0
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hb547adb_0
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.3-h27ca646_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2024.7.4-hf0a4a13_0 --> 2024.8.30-hf0a4a13_0
#   certifi                             2024.7.4-pyhd8ed1ab_0 --> 2024.8.30-pyhd8ed1ab_0
#   openssl                                  3.3.1-hfb2fe0b_2 --> 3.3.1-h8359307_3
#
#
#
# Downloading and Extracting Packages:
# pillow-10.3.0        | 40.8 MB   |                                       |   0%
# matplotlib-base-3.9. | 7.5 MB    |                                       |   0%
#
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
#
#
# fonttools-4.53.1     | 2.6 MB    |                                       |   0%
#
#
#
# freetype-2.12.1      | 582 KB    |                                       |   0%
#
#
#
#
# libjpeg-turbo-3.0.0  | 535 KB    |                                       |   0%
#
#
#
#
#
# qhull-2020.2         | 504 KB    |                                       |   0%
#
#
#
#
#
#
# libxcb-1.15          | 327 KB    |                                       |   0%
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 309 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 281 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 273 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.43        | 258 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 242 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.6.0        | 233 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 207 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.8.30    | 160 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.1.4      | 88 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.5     | 60 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.20      | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# openssl-3.3.1        | 2.8 MB    | 8                                     |   2%
#
#
#
# freetype-2.12.1      | 582 KB    | #                                     |   3%
# matplotlib-base-3.9. | 7.5 MB    |                                       |   0%
#
#
#
# pillow-10.3.0        | 40.8 MB   |                                       |   0%
#
# openssl-3.3.1        | 2.8 MB    | ##########9                           |  29%
#
#
# fonttools-4.53.1     | 2.6 MB    | 2                                     |   1%
# matplotlib-base-3.9. | 7.5 MB    | #1                                    |   3%
#
#
#
# freetype-2.12.1      | 582 KB    | ##################################### | 100%
#
# pillow-10.3.0        | 40.8 MB   | 2                                     |   1%
#
#
#
#
# libjpeg-turbo-3.0.0  | 535 KB    | #1                                    |   3%
# matplotlib-base-3.9. | 7.5 MB    | ##9                                   |   8%
#
#
# pillow-10.3.0        | 40.8 MB   | 5                                     |   1%
# matplotlib-base-3.9. | 7.5 MB    | ####3                                 |  12%
#
#
#
#
# libjpeg-turbo-3.0.0  | 535 KB    | #######################2              |  63%
#
#
# fonttools-4.53.1     | 2.6 MB    | ########2                             |  22%
#
#
#
#
# libjpeg-turbo-3.0.0  | 535 KB    | ##################################### | 100%
#
# pillow-10.3.0        | 40.8 MB   | 8                                     |   2%
# matplotlib-base-3.9. | 7.5 MB    | ######                                |  16%
#
#
# fonttools-4.53.1     | 2.6 MB    | ############9                         |  35%
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | #1                                    |   3%
#
# openssl-3.3.1        | 2.8 MB    | ###########################2          |  74%
# matplotlib-base-3.9. | 7.5 MB    | #######6                              |  21%
#
#
# fonttools-4.53.1     | 2.6 MB    | #################5                    |  48%
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | #4                                    |   4%
#
# openssl-3.3.1        | 2.8 MB    | ###############################       |  84%
# matplotlib-base-3.9. | 7.5 MB    | #########3                            |  25%
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##################################### | 100%
#
#
# pillow-10.3.0        | 40.8 MB   | #7                                    |   5%
#
#
#
#
#
#
# libxcb-1.15          | 327 KB    | #8                                    |   5%
#
# openssl-3.3.1        | 2.8 MB    | ###################################2  |  95%
#
#
# fonttools-4.53.1     | 2.6 MB    | ###########################1          |  73%
# matplotlib-base-3.9. | 7.5 MB    | ##########5                           |  29%
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ##                                    |   5%
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 309 KB    | #9                                    |   5%
#
# openssl-3.3.1        | 2.8 MB    | ##################################### | 100%
#
#
# fonttools-4.53.1     | 2.6 MB    | ###############################6      |  85%
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ##3                                   |   6%
# matplotlib-base-3.9. | 7.5 MB    | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 273 KB    | ##1                                   |   6%
#
#
# fonttools-4.53.1     | 2.6 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 273 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ##7                                   |   7%
# matplotlib-base-3.9. | 7.5 MB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.43        | 258 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 281 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 242 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ###                                   |   8%
# matplotlib-base-3.9. | 7.5 MB    | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.6.0        | 233 KB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 242 KB    | ##################################### | 100%
#
#
# fonttools-4.53.1     | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.6.0        | 233 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ###3                                  |   9%
# matplotlib-base-3.9. | 7.5 MB    | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.8.30    | 160 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.8.30    | 160 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 207 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.1.4      | 88 KB     | ######7                               |  18%
# matplotlib-base-3.9. | 7.5 MB    | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.1.4      | 88 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.20      | 53 KB     | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.20      | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 28 KB     | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# matplotlib-base-3.9. | 7.5 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | ####7                                 |  13% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.5     | 60 KB     | #########9                            |  27%
# matplotlib-base-3.9. | 7.5 MB    | ####################5                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 40.8 MB   | #####3                                |  14%
# pillow-10.3.0        | 40.8 MB   | #####9                                |  16%
# pillow-10.3.0        | 40.8 MB   | ######5                               |  18%
# pillow-10.3.0        | 40.8 MB   | #######1                              |  19%
# pillow-10.3.0        | 40.8 MB   | #######7                              |  21%
# pillow-10.3.0        | 40.8 MB   | ########2                             |  22%
# pillow-10.3.0        | 40.8 MB   | ##########2                           |  28%
# pillow-10.3.0        | 40.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Exercise 1 (Fill in the blanks)

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='red', linestyle='dashed',
             marker=?, markerfacecolor='yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc = 'bottom right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1398, in _to_unmasked_float_array(x)
#    1397 else:
# -> 1398     return np.asarray(x, float)
#
# ValueError: could not convert string to float: 'circle'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       4 y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
#       5 x_err = .25
# ----> 7 plt.errorbar(x, y,
#       8              xerr=x_err, yerr=y_err,
#       9              color='red', linestyle='dashed',
#      10              marker='circle', markerfacecolor='yellow',
#      11              ecolor='black',capsize=5,
#      12              label='Y values with errors')
#      13 plt.xlabel('x-values')
#      14 plt.ylabel('y-values')
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3246, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    3225 @_copy_docstring_and_deprecators(Axes.errorbar)
#    3226 def errorbar(
#    3227     x: float | ArrayLike,
#    (...)
#    3244     **kwargs,
#    3245 ) -> ErrorbarContainer:
# -> 3246     return gca().errorbar(
#    3247         x,
#    3248         y,
#    3249         yerr=yerr,
#    3250         xerr=xerr,
#    3251         fmt=fmt,
#    3252         ecolor=ecolor,
#    3253         elinewidth=elinewidth,
#    3254         capsize=capsize,
#    3255         barsabove=barsabove,
#    3256         lolims=lolims,
#    3257         uplims=uplims,
#    3258         xlolims=xlolims,
#    3259         xuplims=xuplims,
#    3260         errorevery=errorevery,
#    3261         capthick=capthick,
#    3262         **({"data": data} if data is not None else {}),
#    3263         **kwargs,
#    3264     )
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:3644, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3638 kwargs['label'] = '_nolegend_'
#    3640 # Create the main line and determine overall kwargs for child artists.
#    3641 # We avoid calling self.plot() directly, or self._get_lines(), because
#    3642 # that would call self._process_unit_info again, and do other indirect
#    3643 # data processing.
# -> 3644 (data_line, base_style), = self._get_lines._plot_args(
#    3645     self, (x, y) if fmt == '' else (x, y, fmt), kwargs, return_kwargs=True)
#    3647 # Do this after creating `data_line` to avoid modifying `base_style`.
#    3648 if barsabove:
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:532, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     527 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     528                       {**kwargs, 'label': label})
#     529           for j, label in enumerate(labels))
#     531 if return_kwargs:
# --> 532     return list(result)
#     533 else:
#     534     return [l[0] for l in result]
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:527, in <genexpr>(.0)
#     522 else:
#     523     raise ValueError(
#     524         f"label must be scalar or have the same length as the input "
#     525         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 527 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     528                       {**kwargs, 'label': label})
#     529           for j, label in enumerate(labels))
#     531 if return_kwargs:
#     532     return list(result)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:335, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     333 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     334 self._setdefaults(self._getdefaults(kw), kw)
# --> 335 seg = mlines.Line2D(x, y, **kw)
#     336 return seg, kw
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/lines.py:380, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     378     marker = 'none'  # Default.
#     379 if not isinstance(marker, MarkerStyle):
# --> 380     self._marker = MarkerStyle(marker, fillstyle)
#     381 else:
#     382     self._marker = marker
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/markers.py:248, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247 self._set_fillstyle(fillstyle)
# --> 248 self._set_marker(marker)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/markers.py:329, in MarkerStyle._set_marker(self, marker)
#     327         self._marker_function = self._set_vertices
#     328     except ValueError as err:
# --> 329         raise ValueError(
#     330             f'Unrecognized marker style {marker!r}') from err
#     332 if not isinstance(marker, MarkerStyle):
#     333     self._marker = marker
#
# ValueError: Unrecognized marker style 'circle'
